# %%
import pandas as pd

# %%
df_videogames = pd.read_csv("videogames.csv", index_col = 0)

# %%
df_videogames
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
df_videogames.to_excel("videogames.xlsx")

# %%
df_videogames_excel = pd.read_excel("videogames.xlsx", index_col = 0)

# %%
df_videogames_excel
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
df_videogames_excel.to_csv("files/videogames2.csv")

# %%
df = pd.read_json("files/personal.json")

# %%
df.head()
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 40, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
import json

# %%
with open("files/personal.json", "r") as fichero:
    personal = json.load(fichero)

# %%
personal
# Out:
# {'workers': [{'nombre': 'Ana',
#    'edad': 40,
#    'experiencia': 5,
#    'nivel': 'Senior',
#    'salario': 50000,
#    'mascota': 'perros'},
#   {'nombre': 'Eva',
#    'edad': 37,
#    'experiencia': 2,
#    'nivel': 'Mid',
#    'salario': 35000},
#   {'nombre': 'Marta',
#    'edad': 27,
#    'experiencia': 1,
#    'nivel': 'Junior',
#    'salario': 25000},
#   {'nombre': 'Paula',
#    'edad': 30,
#    'experiencia': 3,
#    'nivel': 'Mid',
#    'salario': 35000}]}

# %%
lista_personal = personal["workers"]
lista_personal
# Out:
# [{'nombre': 'Ana',
#   'edad': 40,
#   'experiencia': 5,
#   'nivel': 'Senior',
#   'salario': 50000,
#   'mascota': 'perros'},
#  {'nombre': 'Eva',
#   'edad': 37,
#   'experiencia': 2,
#   'nivel': 'Mid',
#   'salario': 35000},
#  {'nombre': 'Marta',
#   'edad': 27,
#   'experiencia': 1,
#   'nivel': 'Junior',
#   'salario': 25000},
#  {'nombre': 'Paula',
#   'edad': 30,
#   'experiencia': 3,
#   'nivel': 'Mid',
#   'salario': 35000}]

# %%
with open("files/lista_personal.json", "w") as fichero:
    json.dump(lista_personal,fichero)

# %%
df_lista_personal = pd.read_json("files/lista_personal.json")

# %%
df_lista_personal.head()
# Out:
#   nombre  edad  experiencia   nivel  salario mascota
# 0    Ana    40            5  Senior    50000  perros
# 1    Eva    37            2     Mid    35000     NaN
# 2  Marta    27            1  Junior    25000     NaN
# 3  Paula    30            3     Mid    35000     NaN
